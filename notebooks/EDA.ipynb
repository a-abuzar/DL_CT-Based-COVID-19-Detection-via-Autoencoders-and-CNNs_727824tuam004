# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook explores the CT scan dataset for COVID-19 and non-COVID classes.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from glob import glob

data_dir = '../data'
covid_dir = os.path.join(data_dir, 'COVID')
non_covid_dir = os.path.join(data_dir, 'non-COVID')

covid_images = glob(os.path.join(covid_dir, '*.*'))
non_covid_images = glob(os.path.join(non_covid_dir, '*.*'))

print(f"Total COVID-19 scans: {len(covid_images)}")
print(f"Total non-COVID scans: {len(non_covid_images)}")
# Out:
# Total COVID-19 scans: 1272
# Total non-COVID scans: 1249

# %% [markdown]
# ## Class Distribution

# %%
labels = ['COVID', 'non-COVID']
counts = [len(covid_images), len(non_covid_images)]

plt.figure(figsize=(8, 6))
sns.barplot(x=labels, y=counts, palette='viridis')
plt.title('Class Distribution of CT Scans')
plt.ylabel('Number of Images')
plt.show()
# Out:
# C:\Users\abuza\AppData\Local\Temp\ipykernel_13868\230566759.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=labels, y=counts, palette='viridis')

# %% [markdown]
# ## Sample Visualizations

# %%
def show_samples(image_paths, title):
    plt.figure(figsize=(15, 5))
    for i in range(5):
        if i < len(image_paths):
            img = cv2.imread(image_paths[i], cv2.IMREAD_GRAYSCALE)
            plt.subplot(1, 5, i+1)
            plt.imshow(img, cmap='gray')
            plt.title(f"Shape: {img.shape}")
            plt.axis('off')
    plt.suptitle(title)
    plt.show()

show_samples(covid_images[:5], 'Sample COVID-19 Scans')
show_samples(non_covid_images[:5], 'Sample non-COVID Scans')
